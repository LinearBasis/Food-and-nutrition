# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
df = pd.read_csv("..//epi_r.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/zz/zyxvpxvq6csfxvn_n0001rn8000f5_/T/ipykernel_8146/3095012072.py in <module>
# ----> 1 df = pd.read_csv("./epi_r.csv")
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './epi_r.csv'

# %%
df['rating'].value_counts()
# Out:
# 4.375    8019
# 3.750    5169
# 5.000    2719
# 0.000    1836
# 3.125    1489
# 2.500     532
# 1.250     164
# 1.875     124
# Name: rating, dtype: int64

# %%
df_nutr = pd.read_csv("../../Nutrition-recommendations/data/Nutrients.csv")
df_nutr
# Out:
#             Nutrient       Unit of measure  Adults and Children >= 4 years  \
# 0          Vitamin A  Micrograms RAE (mcg)                          900.00
# 1          Vitamin C       Milligrams (mg)                           90.00
# 2            Calcium       Milligrams (mg)                            1.30
# 3               Iron       Milligrams (mg)                           18.00
# 4          Vitamin D      Micrograms (mcg)                           20.00
# 5          Vitamin E       Milligrams (mg)                           15.00
# 6          Vitamin K      Micrograms (mcg)                          120.00
# 7            Thiamin       Milligrams (mg)                            1.20
# 8         Riboflavin       Milligrams (mg)                            1.30
# 9             Niacin    Milligrams NE (mg)                           16.00
# 10       Vitamin B-6       Milligrams (mg)                            1.70
# 11            Folate  Micrograms DFE (mcg)                          400.00
# 12      Vitamin B-12      Micrograms (mcg)                            2.40
# 13            Biotin      Micrograms (mcg)                           30.00
# 14  Pantothenic acid       Milligrams (mg)                            5.00
# 15        Phosphorus       Milligrams (mg)                            1.25
# 16            Iodine      Micrograms (mcg)                          150.00
# 17         Mahnesium       Milligrams (mg)                          420.00
# 18              Zinc       Milligrams (mg)                           11.00
# 19          Selenium      Micrograms (mcg)                           55.00
# 20            Copper       Milligrams (mg)                            0.90
# 21         Manganese       Milligrams (mg)                            2.30
# 22          Chromium      Micrograms (mcg)                           35.00
# 23        Molybdenum      Micrograms (mcg)                           45.00
# 24          Chloride       Milligrams (mg)                            2.30
# 25         Potassium       Milligrams (mg)                            4.70
# 26           Choline       Milligrams (mg)                          550.00
# 27           Protein             Grams (g)                             NaN
#
#     Infants through 12 months  Children 1 through 3 years  \
# 0                       500.0                       300.0
# 1                        50.0                        15.0
# 2                       260.0                       700.0
# 3                        11.0                         7.0
# 4                        10.0                        15.0
# 5                         5.0                         6.0
# 6                         2.5                        30.0
# 7                         0.3                         0.5
# 8                         0.4                         0.5
# 9                         4.0                         6.0
# 10                        0.3                         0.5
# 11                       80.0                       150.0
# 12                        0.5                         0.9
# 13                        6.0                         8.0
# 14                        1.8                         2.0
# 15                      275.0                       460.0
# 16                      130.0                        90.0
# 17                       75.0                        80.0
# 18                        3.0                         3.0
# 19                       20.0                        20.0
# 20                        0.2                         0.3
# 21                        0.6                         1.2
# 22                        5.5                        11.0
# 23                        3.0                        17.0
# 24                      570.0                         1.5
# 25                      700.0                         3.0
# 26                      150.0                       200.0
# 27                       11.0                         NaN
#
#     Pregnant women and lacting women
# 0                               1.30
# 1                             120.00
# 2                               1.30
# 3                              27.00
# 4                              15.00
# 5                              19.00
# 6                              90.00
# 7                               1.40
# 8                               1.60
# 9                              18.00
# 10                              2.00
# 11                            600.00
# 12                              2.80
# 13                             35.00
# 14                              7.00
# 15                              1.25
# 16                            290.00
# 17                            400.00
# 18                             13.00
# 19                             70.00
# 20                              1.30
# 21                              2.60
# 22                             45.00
# 23                             50.00
# 24                              2.30
# 25                              5.10
# 26                            550.00
# 27                             71.00

# %%
class NutruientParser:
    def __init__(self, product_name):
        self.product_name = product_name

        self.r = requests.get(
            f"https://api.nal.usda.gov/fdc/v1/foods/search?api_key=O9O8y67XB59UcnngfKt1eP4yX7Vm0ro7N66HxQtm&query={product_name}", verify = False
        )
        self.json_data = r.json()
        self.df_nutr = pd.read_csv("../../tmp/data/Nutrients.csv")
    
    def parse_nutricious_values_per_product():
        
                
        
#     def parse_product
    

# with open("a.json", "w") as f:
#     f.write(str(json_data))
# Out:
# /Users/tquintan/Library/Python/3.7/lib/python/site-packages/urllib3/connectionpool.py:1050: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nal.usda.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
arr = np.array()

for index in range(len(json_data["foods"])):
    for i in json_data["foods"][index]["foodNutrients"]:
        if "Protein" in i["nutrientName"]:
            i['value']
# Out:
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.39
#
#
# 3.33
#
#
# 3.75
#
#
# 3.33
#
#
# 3.39
#
#
# 3.33
#
#
# 3.75
#
#
# 3.33
#
#
# 3.33
#
#
# 3.39
#
#
# 3.33
#
#
# 3.75
#
#
# 4.17
#
#
# 3.33
#
#
# 3.38
#
#
# 3.33
#
#
# 3.75
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 34.8
#
#
# 3.39
#
#
# 3.33
#
#
# 3.33
#
#
# 3.38
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.75
#
#
# 3.39
#
#
# 3.33
#
#
# 3.75
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 3.33
#
#
# 4.24
#
#
# 3.28
#
#
# 0.21
#
#
# 7.6
#
#
# 7.6
#
#
# 1.03

# %%
len(json_data["foods"])
# Out:
# 50

# %%
# !ls
